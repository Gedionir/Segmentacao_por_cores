# %% [markdown]
# <a href="https://colab.research.google.com/github/Gedionir/Segmentacao_por_cores/blob/main/Segmentacao_cores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import sys
import cv2 as imshow


if "google.colab" in sys.modules:
  import subprocess
  subprocess.call("apt-get install subversion".split())
  subprocess.call(" svn export https://cdn.paytour.com.br/assets/images/passeios-193/a9900b420e34ca179be1f684e5acb45d/WhatsApp%20Image%202022-04-15%20at%2019.29.18.jpeg".split())

# %%
figsize = (10, 10)

# %%
bgr_im = cv2.imread('grass.jpg')
rgb_im = cv2.cvtColor(bgr_im, cv2.COLOR_BGR2RGB)
plt.figure(figsize=figsize)
plt.imshow(rgb_im)
plt.title("Imagem do Campo")
plt.show()

# %% [markdown]
# ####Convertendo imagem RGB para HSV.

# %%
rgb_green = np.uint8([[[0, 255, 0]]]) # Matriz 3D - separando o verde
hsv_green = cv2.cvtColor(rgb_green, cv2.COLOR_RGB2HSV)[0, 0, :]
print(hsv_green)
# Out:
# [ 60 255 255]

# %%
thresholding_schematics = cv2.cvtColor(cv2.imread('hsv_th.jpg'), cv2.COLOR_BGR2RGB)
plt.figure(figsize=figsize)
plt.imshow(thresholding_schematics)
plt.title("thresholding_schematics")
plt.show()

# %%
#Convertendo imagem RGB para HSV
hsv_im = cv2.cvtColor(rgb_im, cv2.COLOR_RGB2HSV)

#Definir faixa de matiz e intensidade
lower_th = hsv_green - np.array([70, 200, 200])
upper_th = hsv_green + np.array([30, 0, 0])

#Limitando a imagem HSV
mask = cv2.inRange(hsv_im, lower_th, upper_th)

plt.figure(figsize=figsize)
plt.imshow(mask)
plt.title("Resultado da Máscara")
plt.show()
